# %%
# Surface[1] = type=S radius=0 thickness=4 diameter = 105.5 nd = 1.5168 vd = 64.12
# Surface[2] = type=S radius=0 thickness=0.6 diameter = 105.5 nd = 0 vd = 0
# Surface[3] = type=S radius=173.8655 thickness=12 diameter = 103.9 nd = 1.49782 vd = 82.52
# Surface[4] = type=S radius=-978.0647 thickness=0.2 diameter = 103.9 nd = 0 vd = 0
# Surface[5] = type=S radius=134.205 thickness=15 diameter = 99.62 nd = 1.49782 vd = 82.52
# Surface[6] = type=S radius=-460.575 thickness=5 diameter = 98.3 nd = 1.804 vd = 46.57
# Surface[7] = type=S radius=332.9139 thickness=46.3 diameter = 98.3 nd = 0 vd = 0
# Surface[8] = type=S radius=99.3587 thickness=3.5 diameter = 74.82 nd = 1.743997 vd = 44.79
# Surface[9] = type=S radius=55.691 thickness=15.9 diameter = 69.5 nd = 1.49782 vd = 82.52
# Surface[10] = type=S radius=-1333.1846 thickness=29.7073 diameter = 69.5 nd = 0 vd = 0
# Surface[11] = type=S radius=-169.9686 thickness=2.7 diameter = 44.04 nd = 1.5168 vd = 64.05
# Surface[12] = type=S radius=67.2847 thickness=4.51 diameter = 42 nd = 0 vd = 0
# Surface[13] = type=S radius=-192.9273 thickness=7 diameter = 42 nd = 1.80384 vd = 33.89
# Surface[14] = type=S radius=-43.081 thickness=2.8 diameter = 42 nd = 1.58913 vd = 61.29
# Surface[15] = type=S radius=83.8867 thickness=20.1028 diameter = 42 nd = 0 vd = 0
# Surface[16] = type=AS radius=0 thickness=1.7 diameter = 38.661 nd = 0 vd = 0
# Surface[17] = type=S radius=203.1344 thickness=5.1 diameter = 40.5 nd = 1.518601 vd = 69.92
# Surface[18] = type=S radius=-99.7742 thickness=3.057 diameter = 40.5 nd = 0 vd = 0
# Surface[19] = type=S radius=-42.995 thickness=2.5 diameter = 40.5 nd = 1.79504 vd = 28.48
# Surface[20] = type=S radius=-61.848 thickness=9.1 diameter = 41.72 nd = 0 vd = 0
# Surface[21] = type=S radius=-176.5352 thickness=4.7 diameter = 43.1 nd = 1.518601 vd = 69.92
# Surface[22] = type=S radius=-53.374 thickness=19.1 diameter = 43.1 nd = 0 vd = 0
# Surface[23] = type=S radius=0 thickness=2 diameter = 49.41 nd = 1.5168 vd = 64.12
# Surface[24] = type=S radius=0 thickness=86.55 diameter = 49.41 nd = 0 vd = 0
# %matplotlib inline
isdark = False
from rayoptics.environment import *
from rayoptics.elem.elements import Element
from rayoptics.raytr.trace import apply_paraxial_vignetting

# JP2015-102734 Example 1 ML (Nikon AF-S Nikkor 300mm f2.8D IF-ED II)
# Obtained via https://www.photonstophotos.net/GeneralTopics/Lenses/OpticalBench/OpticalBenchHub.htm

opm = OpticalModel()
sm  = opm.seq_model
osp = opm.optical_spec
pm = opm.parax_model
osp.pupil = PupilSpec(osp, key=['image', 'f/#'], value=2.87875)
osp.field_of_view = FieldSpec(osp, key=['object', 'angle'], flds=[0., 4.17])
osp.spectral_region = WvlSpec([(486.1327, 0.5), (587.5618, 1.0), (656.2725, 0.5)], ref_wl=1)
opm.system_spec.title = 'JP2015-102734 Example 1 ML (Nikon AF-S Nikkor 300mm f2.8D IF-ED II)'
opm.system_spec.dimensions = 'MM'
opm.radius_mode = True
sm.gaps[0].thi=1e10
sm.add_surface([0,4,1.5168,64.12])
sm.ifcs[sm.cur_surface].max_aperture = 52.75
sm.add_surface([0,0.6])
sm.ifcs[sm.cur_surface].max_aperture = 52.75
sm.add_surface([173.865,12,1.49782,82.52])
sm.ifcs[sm.cur_surface].max_aperture = 51.95
sm.add_surface([-978.065,0.2])
sm.ifcs[sm.cur_surface].max_aperture = 51.95
sm.add_surface([134.205,15,1.49782,82.52])
sm.ifcs[sm.cur_surface].max_aperture = 49.81
sm.add_surface([-460.575,5,1.804,46.57])
sm.ifcs[sm.cur_surface].max_aperture = 49.15
sm.add_surface([332.914,46.3])
sm.ifcs[sm.cur_surface].max_aperture = 49.15
sm.add_surface([99.3587,3.5,1.744,44.79])
sm.ifcs[sm.cur_surface].max_aperture = 37.41
sm.add_surface([55.691,15.9,1.49782,82.52])
sm.ifcs[sm.cur_surface].max_aperture = 34.75
sm.add_surface([-1333.18,29.7073])
sm.ifcs[sm.cur_surface].max_aperture = 34.75
sm.add_surface([-169.969,2.7,1.5168,64.05])
sm.ifcs[sm.cur_surface].max_aperture = 22.02
sm.add_surface([67.2847,4.51])
sm.ifcs[sm.cur_surface].max_aperture = 21
sm.add_surface([-192.927,7,1.80384,33.89])
sm.ifcs[sm.cur_surface].max_aperture = 21
sm.add_surface([-43.081,2.8,1.58913,61.29])
sm.ifcs[sm.cur_surface].max_aperture = 21
sm.add_surface([83.8867,20.1028])
sm.ifcs[sm.cur_surface].max_aperture = 21
sm.add_surface([0,1.7])
sm.set_stop()
sm.ifcs[sm.cur_surface].max_aperture = 19.3305
sm.add_surface([203.134,5.1,1.5186,69.92])
sm.ifcs[sm.cur_surface].max_aperture = 20.25
sm.add_surface([-99.7742,3.057])
sm.ifcs[sm.cur_surface].max_aperture = 20.25
sm.add_surface([-42.995,2.5,1.79504,28.48])
sm.ifcs[sm.cur_surface].max_aperture = 20.25
sm.add_surface([-61.848,9.1])
sm.ifcs[sm.cur_surface].max_aperture = 20.86
sm.add_surface([-176.535,4.7,1.5186,69.92])
sm.ifcs[sm.cur_surface].max_aperture = 21.55
sm.add_surface([-53.374,19.1])
sm.ifcs[sm.cur_surface].max_aperture = 21.55
sm.add_surface([0,2,1.5168,64.12])
sm.ifcs[sm.cur_surface].max_aperture = 24.705
sm.add_surface([0,86.55])
sm.ifcs[sm.cur_surface].max_aperture = 24.705
sm.list_surfaces()
sm.list_gaps()
sm.do_apertures = False
opm.update_model()
apply_paraxial_vignetting(opm)
layout_plt = plt.figure(FigureClass=InteractiveLayout, opt_model=opm, do_draw_rays=True, do_paraxial_layout=False,
                        is_dark=isdark).plot()
sm.list_model()
# List the optical specifications
pm.first_order_data()
# List the paraxial model
pm.list_lens()
# Plot the transverse ray aberrations
abr_plt = plt.figure(FigureClass=RayFanFigure, opt_model=opm,
          data_type='Ray', scale_type=Fit.All_Same, is_dark=isdark).plot()
# Plot the wavefront aberration
wav_plt = plt.figure(FigureClass=RayFanFigure, opt_model=opm,
          data_type='OPD', scale_type=Fit.All_Same, is_dark=isdark).plot()
# Plot spot diagrams
spot_plt = plt.figure(FigureClass=SpotDiagramFigure, opt_model=opm,
                      scale_type=Fit.User_Scale, user_scale_value=0.1, is_dark=isdark).plot()
# Out:
# 0 Surface(lbl='Obj', profile=Spherical(c=0.0), interact_mode='dummy')
# 1 Surface(profile=Spherical(c=0.0), interact_mode='transmit')
# 2 Surface(profile=Spherical(c=0.0), interact_mode='transmit')
# 3 Surface(profile=Spherical(c=0.0057515888764271125), interact_mode='transmit')
# 4 Surface(profile=Spherical(c=-0.0010224269348151707), interact_mode='transmit')
# 5 Surface(profile=Spherical(c=0.0074512872098655035), interact_mode='transmit')
# 6 Surface(profile=Spherical(c=-0.0021711990446724202), interact_mode='transmit')
# 7 Surface(profile=Spherical(c=0.00300377875367212), interact_mode='transmit')
# 8 Surface(profile=Spherical(c=0.010064543920159987), interact_mode='transmit')
# 9 Surface(profile=Spherical(c=0.01795622272898673), interact_mode='transmit')
# 10 Surface(profile=Spherical(c=-0.0007500862599198908), interact_mode='transmit')
# 11 Surface(profile=Spherical(c=-0.005883425801175509), interact_mode='transmit')
# ...

# %%
opm = OpticalModel()
sm  = opm.seq_model
osp = opm.optical_spec
pm = opm.parax_model
osp.pupil = PupilSpec(osp, key=['image', 'f/#'], value=2.87875)
osp.field_of_view = FieldSpec(osp, key=['object', 'angle'], flds=[0., 4.17])
osp.spectral_region = WvlSpec([(486.1327, 0.5), (587.5618, 1.0), (656.2725, 0.5)], ref_wl=1)
opm.system_spec.title = 'JP2015-102734 Example 1 ML (Nikon AF-S Nikkor 300mm f2.8D IF-ED II)'
opm.system_spec.dimensions = 'MM'
opm.radius_mode = True
sm.gaps[0].thi=1e10
sm.add_surface([0,4,'J-BK7A','Hikari'])         # 1.5168,64.12   64.14
sm.ifcs[sm.cur_surface].max_aperture = 52.75
sm.add_surface([0,0.6])
sm.ifcs[sm.cur_surface].max_aperture = 52.75
sm.add_surface([173.865,12,'J-FKH1', 'Hikari'])       # 1.49782,82.52   82.57
sm.ifcs[sm.cur_surface].max_aperture = 51.95
sm.add_surface([-978.065,0.2])
sm.ifcs[sm.cur_surface].max_aperture = 51.95
sm.add_surface([134.205,15,'J-FKH1', 'Hikari'])       # 1.49782,82.52   82.57
sm.ifcs[sm.cur_surface].max_aperture = 49.81
sm.add_surface([-460.575,5,'J-LASF015', 'Hikari'])    # 1.804,46.57   46.6
sm.ifcs[sm.cur_surface].max_aperture = 49.15
sm.add_surface([332.914,46.3])
sm.ifcs[sm.cur_surface].max_aperture = 49.15
sm.add_surface([99.3587,3.5,'J-LAF2', 'Hikari'])      # 1.744,44.79   44.81
sm.ifcs[sm.cur_surface].max_aperture = 37.41
sm.add_surface([55.691,15.9,'J-FKH1', 'Hikari'])       # 1.49782,82.52  82.57
sm.ifcs[sm.cur_surface].max_aperture = 34.75
sm.add_surface([-1333.18,29.7073])
sm.ifcs[sm.cur_surface].max_aperture = 34.75
sm.add_surface([-169.969,2.7,'J-BK7A','Hikari'])         # 1.5168,64.05   64.14
sm.ifcs[sm.cur_surface].max_aperture = 22.02
sm.add_surface([67.2847,4.51])
sm.ifcs[sm.cur_surface].max_aperture = 21
sm.add_surface([-192.927,7,1.80384,33.89])
sm.ifcs[sm.cur_surface].max_aperture = 21
sm.add_surface([-43.081,2.8,'J-SK5','Hikari'])           # 1.58913,61.29  61.22
sm.ifcs[sm.cur_surface].max_aperture = 21
sm.add_surface([83.8867,20.1028])
sm.ifcs[sm.cur_surface].max_aperture = 21
sm.add_surface([0,1.7])
sm.set_stop()
sm.ifcs[sm.cur_surface].max_aperture = 19.3305
sm.add_surface([203.134,5.1,'J-PKH1', 'Hikari'])         # 1.5186,69.92   69.89
sm.ifcs[sm.cur_surface].max_aperture = 20.25
sm.add_surface([-99.7742,3.057])
sm.ifcs[sm.cur_surface].max_aperture = 20.25
sm.add_surface([-42.995,2.5,'J-LAFH3', 'Hikari'])        # 1.79504,28.48
sm.ifcs[sm.cur_surface].max_aperture = 20.25
sm.add_surface([-61.848,9.1])
sm.ifcs[sm.cur_surface].max_aperture = 20.86
sm.add_surface([-176.535,4.7,'J-PKH1', 'Hikari'])         # 1.5186,69.92  69.89
sm.ifcs[sm.cur_surface].max_aperture = 21.55
sm.add_surface([-53.374,19.1])
sm.ifcs[sm.cur_surface].max_aperture = 21.55
sm.add_surface([0,2,'J-BK7A','Hikari'])         # 1.5168,64.12    64.14
sm.ifcs[sm.cur_surface].max_aperture = 24.705
sm.add_surface([0,86.55])
sm.ifcs[sm.cur_surface].max_aperture = 24.705
sm.list_surfaces()
sm.list_gaps()
sm.do_apertures = False
opm.update_model()
apply_paraxial_vignetting(opm)
layout_plt = plt.figure(FigureClass=InteractiveLayout, opt_model=opm, do_draw_rays=True, do_paraxial_layout=False,
                        is_dark=isdark).plot()
sm.list_model()
# List the optical specifications
pm.first_order_data()
# List the paraxial model
pm.list_lens()
# Plot the transverse ray aberrations
abr_plt = plt.figure(FigureClass=RayFanFigure, opt_model=opm,
          data_type='Ray', scale_type=Fit.All_Same, is_dark=isdark).plot()
# Plot the wavefront aberration
wav_plt = plt.figure(FigureClass=RayFanFigure, opt_model=opm,
          data_type='OPD', scale_type=Fit.All_Same, is_dark=isdark).plot()
# Plot spot diagrams
spot_plt = plt.figure(FigureClass=SpotDiagramFigure, opt_model=opm,
                      scale_type=Fit.User_Scale, user_scale_value=0.1, is_dark=isdark).plot()
# Out:
# 0 Surface(lbl='Obj', profile=Spherical(c=0.0), interact_mode='dummy')
# 1 Surface(profile=Spherical(c=0.0), interact_mode='transmit')
# 2 Surface(profile=Spherical(c=0.0), interact_mode='transmit')
# 3 Surface(profile=Spherical(c=0.0057515888764271125), interact_mode='transmit')
# 4 Surface(profile=Spherical(c=-0.0010224269348151707), interact_mode='transmit')
# 5 Surface(profile=Spherical(c=0.0074512872098655035), interact_mode='transmit')
# 6 Surface(profile=Spherical(c=-0.0021711990446724202), interact_mode='transmit')
# 7 Surface(profile=Spherical(c=0.00300377875367212), interact_mode='transmit')
# 8 Surface(profile=Spherical(c=0.010064543920159987), interact_mode='transmit')
# 9 Surface(profile=Spherical(c=0.01795622272898673), interact_mode='transmit')
# 10 Surface(profile=Spherical(c=-0.0007500862599198908), interact_mode='transmit')
# 11 Surface(profile=Spherical(c=-0.005883425801175509), interact_mode='transmit')
# ...

# %%
from rayoptics.environment import *

gls = create_glass('J-BK7A','Hikari')
print(gls.rindex('d'))
# Out:
# 1.5168000094330314
