# %%
# %matplotlib inline
isdark = False
from rayoptics.environment import *
from rayoptics.elem.elements import Element
from rayoptics.raytr.trace import apply_paraxial_vignetting

# JP2019-152887 Example 3 (Nikon AF-S Nikkor 400mm f/2.8 E FL ED VR)
# Obtained via https://www.photonstophotos.net/GeneralTopics/Lenses/OpticalBench/OpticalBenchHub.htm

opm = OpticalModel()
sm  = opm.seq_model
osp = opm.optical_spec
pm = opm.parax_model
osp.pupil = PupilSpec(osp, key=['image', 'f/#'], value=2.89)
osp.field_of_view = FieldSpec(osp, key=['object', 'angle'], flds=[0., 3.14])
osp.spectral_region = WvlSpec([(486.1327, 0.5), (587.5618, 1.0), (656.2725, 0.5)], ref_wl=1)
opm.system_spec.title = 'JP2019-152887 Example 3 (Nikon AF-S Nikkor 400mm f/2.8 E FL ED VR)'
opm.system_spec.dimensions = 'MM'
opm.radius_mode = True
sm.gaps[0].thi=1e10
sm.add_surface([1200.37,5,1.5168,63.88])
sm.ifcs[sm.cur_surface].max_aperture = 69.61
sm.add_surface([1199.79,1])
sm.ifcs[sm.cur_surface].max_aperture = 69.61
sm.add_surface([207.079,17.5,1.43384,95.26])
sm.ifcs[sm.cur_surface].max_aperture = 68.61
sm.add_surface([-1127.53,44.9])
sm.ifcs[sm.cur_surface].max_aperture = 68.61
sm.add_surface([175.97,18,1.43384,95.26])
sm.ifcs[sm.cur_surface].max_aperture = 57.61
sm.add_surface([-397.271,3.07])
sm.ifcs[sm.cur_surface].max_aperture = 57.61
sm.add_surface([-360.24,6,1.61266,44.46])
sm.ifcs[sm.cur_surface].max_aperture = 55.36
sm.add_surface([353.184,90])
sm.ifcs[sm.cur_surface].max_aperture = 55.36
sm.add_surface([66.4844,4,1.795,45.32])
sm.ifcs[sm.cur_surface].max_aperture = 34.61
sm.add_surface([45.9182,15,1.49782,82.54])
sm.ifcs[sm.cur_surface].max_aperture = 31.61
sm.add_surface([1114.11,18.503])
sm.ifcs[sm.cur_surface].max_aperture = 31.61
sm.add_surface([2992.55,2.5,1.755,52.34])
sm.ifcs[sm.cur_surface].max_aperture = 24.11
sm.add_surface([118.04,3.35])
sm.ifcs[sm.cur_surface].max_aperture = 23.36
sm.add_surface([-241.694,3.5,1.84668,23.83])
sm.ifcs[sm.cur_surface].max_aperture = 23.36
sm.add_surface([-86.4136,2.4,1.53996,59.52])
sm.ifcs[sm.cur_surface].max_aperture = 23.36
sm.add_surface([64.2643,38.179])
sm.ifcs[sm.cur_surface].max_aperture = 23.36
sm.add_surface([0,1.5])
sm.set_stop()
sm.ifcs[sm.cur_surface].max_aperture = 18.979
sm.add_surface([90.0336,7.6,1.48749,70.43])
sm.ifcs[sm.cur_surface].max_aperture = 19.36
sm.add_surface([-63.8039,1.2])
sm.ifcs[sm.cur_surface].max_aperture = 19.36
sm.add_surface([-65.9768,1.9,1.84668,23.83])
sm.ifcs[sm.cur_surface].max_aperture = 18.36
sm.add_surface([-114.876,5])
sm.ifcs[sm.cur_surface].max_aperture = 18.36
sm.add_surface([300.359,3.5,1.84668,23.83])
sm.ifcs[sm.cur_surface].max_aperture = 18.36
sm.add_surface([-128.056,1.9,1.59319,67.94])
sm.ifcs[sm.cur_surface].max_aperture = 18.36
sm.add_surface([53.9004,3.1])
sm.ifcs[sm.cur_surface].max_aperture = 18.36
sm.add_surface([-347.542,1.9,1.755,52.33])
sm.ifcs[sm.cur_surface].max_aperture = 17.36
sm.add_surface([94.5337,4.19])
sm.ifcs[sm.cur_surface].max_aperture = 17.36
sm.add_surface([118.353,3.5,1.7725,49.68])
sm.ifcs[sm.cur_surface].max_aperture = 16.86
sm.add_surface([-384.382,0.1])
sm.ifcs[sm.cur_surface].max_aperture = 16.86
sm.add_surface([67.4622,4.5,1.64,60.14])
sm.ifcs[sm.cur_surface].max_aperture = 17.11
sm.add_surface([-340.421,1.9,1.84668,23.83])
sm.ifcs[sm.cur_surface].max_aperture = 17.11
sm.add_surface([246.642,6.5])
sm.ifcs[sm.cur_surface].max_aperture = 17.11
sm.add_surface([0,1.5,1.5168,63.88])
sm.ifcs[sm.cur_surface].max_aperture = 17.86
sm.add_surface([0,74.22])
sm.ifcs[sm.cur_surface].max_aperture = 17.86
sm.list_surfaces()
sm.list_gaps()
sm.do_apertures = False
opm.update_model()
apply_paraxial_vignetting(opm)
layout_plt = plt.figure(FigureClass=InteractiveLayout, opt_model=opm, do_draw_rays=True, do_paraxial_layout=False,
                        is_dark=isdark).plot()
sm.list_model()
# List the optical specifications
pm.first_order_data()
# List the paraxial model
pm.list_lens()
# Plot the transverse ray aberrations
abr_plt = plt.figure(FigureClass=RayFanFigure, opt_model=opm,
          data_type='Ray', scale_type=Fit.All_Same, is_dark=isdark).plot()
# Plot the wavefront aberration
wav_plt = plt.figure(FigureClass=RayFanFigure, opt_model=opm,
          data_type='OPD', scale_type=Fit.All_Same, is_dark=isdark).plot()
# Plot spot diagrams
spot_plt = plt.figure(FigureClass=SpotDiagramFigure, opt_model=opm,
                      scale_type=Fit.User_Scale, user_scale_value=0.1, is_dark=isdark).plot()
# Out:
# 0 Surface(lbl='Obj', profile=Spherical(c=0.0), interact_mode=dummy)
# 1 Surface(profile=Spherical(c=0.000833076468089006), interact_mode=transmit)
# 2 Surface(profile=Spherical(c=0.0008334791921919669), interact_mode=transmit)
# 3 Surface(profile=Spherical(c=0.004829074894122533), interact_mode=transmit)
# 4 Surface(profile=Spherical(c=-0.0008868943620125407), interact_mode=transmit)
# 5 Surface(profile=Spherical(c=0.005682786838665682), interact_mode=transmit)
# 6 Surface(profile=Spherical(c=-0.002517173415628123), interact_mode=transmit)
# 7 Surface(profile=Spherical(c=-0.00277592715967133), interact_mode=transmit)
# 8 Surface(profile=Spherical(c=0.002831385340219262), interact_mode=transmit)
# 9 Surface(profile=Spherical(c=0.015041122428720122), interact_mode=transmit)
# 10 Surface(profile=Spherical(c=0.021777857145968266), interact_mode=transmit)
# 11 Surface(profile=Spherical(c=0.0008975774384935061), interact_mode=transmit)
# 12 Surface(profile=Spherical(c=0.00033416317187682745), interact_mode=transmit)
# 13 Surface(profile=Spherical(c=0.008471704506946797), interact_mode=transmit)
# 14 Surface(profile=Spherical(c=-0.004137463073142072), interact_mode=transmit)
# 15 Surface(profile=Spherical(c=-0.011572252515807697), interact_mode=transmit)
# 16 Surface(profile=Spherical(c=0.015560739010617091), interact_mode=transmit)
# 17 Surface(profile=Spherical(c=0.0), interact_mode=transmit)
# 18 Surface(profile=Spherical(c=0.011106964511026994), interact_mode=transmit)
# 19 Surface(profile=Spherical(c=-0.015673023122411013), interact_mode=transmit)
# 20 Surface(profile=Spherical(c=-0.015156843011482825), interact_mode=transmit)
# 21 Surface(profile=Spherical(c=-0.008705038476270065), interact_mode=transmit)
# 22 Surface(profile=Spherical(c=0.0033293492121095093), interact_mode=transmit)
# 23 Surface(profile=Spherical(c=-0.007809083525957393), interact_mode=transmit)
# 24 Surface(profile=Spherical(c=0.01855273801307597), interact_mode=transmit)
# 25 Surface(profile=Spherical(c=-0.0028773500756743074), interact_mode=transmit)
# 26 Surface(profile=Spherical(c=0.010578238236734625), interact_mode=transmit)
# 27 Surface(profile=Spherical(c=0.00844929997549703), interact_mode=transmit)
# 28 Surface(profile=Spherical(c=-0.002601578637917488), interact_mode=transmit)
# 29 Surface(profile=Spherical(c=0.014823115759640215), interact_mode=transmit)
# 30 Surface(profile=Spherical(c=-0.0029375391059893487), interact_mode=transmit)
# 31 Surface(profile=Spherical(c=0.0040544595000040545), interact_mode=transmit)
# 32 Surface(profile=Spherical(c=0.0), interact_mode=transmit)
# 33 Surface(profile=Spherical(c=0.0), interact_mode=transmit)
# 34 Surface(lbl='Img', profile=Spherical(c=0.0), interact_mode=dummy)
# 0 Gap(t=10000000000.0, medium=Air())
# 1 Gap(t=5, medium=Glass(nd=1.5168, vd=63.88, mat='', cat=''))
# 2 Gap(t=1, medium=Air())
# 3 Gap(t=17.5, medium=Glass(nd=1.43384, vd=95.26, mat='', cat=''))
# 4 Gap(t=44.9, medium=Air())
# 5 Gap(t=18, medium=Glass(nd=1.43384, vd=95.26, mat='', cat=''))
# 6 Gap(t=3.07, medium=Air())
# 7 Gap(t=6, medium=Glass(nd=1.61266, vd=44.46, mat='', cat=''))
# 8 Gap(t=90, medium=Air())
# 9 Gap(t=4, medium=Glass(nd=1.795, vd=45.32, mat='', cat=''))
# 10 Gap(t=15, medium=Glass(nd=1.49782, vd=82.54, mat='', cat=''))
# 11 Gap(t=18.503, medium=Air())
# 12 Gap(t=2.5, medium=Glass(nd=1.755, vd=52.34, mat='', cat=''))
# 13 Gap(t=3.35, medium=Air())
# 14 Gap(t=3.5, medium=Glass(nd=1.84668, vd=23.83, mat='', cat=''))
# 15 Gap(t=2.4, medium=Glass(nd=1.53996, vd=59.52, mat='', cat=''))
# 16 Gap(t=38.179, medium=Air())
# 17 Gap(t=1.5, medium=Air())
# 18 Gap(t=7.6, medium=Glass(nd=1.48749, vd=70.43, mat='', cat=''))
# 19 Gap(t=1.2, medium=Air())
# 20 Gap(t=1.9, medium=Glass(nd=1.84668, vd=23.83, mat='', cat=''))
# 21 Gap(t=5, medium=Air())
# 22 Gap(t=3.5, medium=Glass(nd=1.84668, vd=23.83, mat='', cat=''))
# 23 Gap(t=1.9, medium=Glass(nd=1.59319, vd=67.94, mat='', cat=''))
# 24 Gap(t=3.1, medium=Air())
# 25 Gap(t=1.9, medium=Glass(nd=1.755, vd=52.33, mat='', cat=''))
# 26 Gap(t=4.19, medium=Air())
# 27 Gap(t=3.5, medium=Glass(nd=1.7725, vd=49.68, mat='', cat=''))
# 28 Gap(t=0.1, medium=Air())
# 29 Gap(t=4.5, medium=Glass(nd=1.64, vd=60.14, mat='', cat=''))
# 30 Gap(t=1.9, medium=Glass(nd=1.84668, vd=23.83, mat='', cat=''))
# 31 Gap(t=6.5, medium=Air())
# 32 Gap(t=1.5, medium=Glass(nd=1.5168, vd=63.88, mat='', cat=''))
# 33 Gap(t=74.22, medium=Air())
#              r            t        medium     mode   zdr      sd
#  Obj:     0.000000  1.00000e+10       air             1      1.0000
#    1:  1200.370000      5.00000   517.639             1      69.610
#    2:  1199.790000      1.00000       air             1      69.610
#    3:   207.079000      17.5000   434.953             1      68.610
#    4: -1127.530000      44.9000       air             1      68.610
#    5:   175.970000      18.0000   434.953             1      57.610
#    6:  -397.271000      3.07000       air             1      57.610
#    7:  -360.240000      6.00000   613.445             1      55.360
#    8:   353.184000      90.0000       air             1      55.360
#    9:    66.484400      4.00000   795.453             1      34.610
#   10:    45.918200      15.0000   498.825             1      31.610
#   11:  1114.110000      18.5030       air             1      31.610
#   12:  2992.550000      2.50000   755.523             1      24.110
#   13:   118.040000      3.35000       air             1      23.360
#   14:  -241.694000      3.50000   847.238             1      23.360
#   15:   -86.413600      2.40000   540.595             1      23.360
#   16:    64.264300      38.1790       air             1      23.360
# Stop:     0.000000      1.50000       air             1      18.979
#   18:    90.033600      7.60000   487.704             1      19.360
# 16:     -7.64735      0.200302
# 17: -3.24578e-08      0.200302
# 18:     0.300454      0.198676
# 19:      1.31554      0.188624
# 20:      1.54189      0.208411
# 21:      1.75632      0.195467
# 22:      2.73365      0.187761
# 23:      3.08952      0.181645
# 24:      3.30614       0.21803
# 25:      3.98203      0.226681
# 26:      4.22744      0.260443
# 27:       5.3187      0.225728
# 28:      5.76443      0.214143
# 29:      5.78584      0.159254
# 30:      6.22282      0.163032
# 31:      6.39056       0.18497
# 32:      7.59286       0.18497
# 33:      7.77578       0.18497
# 34:      21.5042       0.18497
#
#             power           tau        index    type
#  0:             0         1e+10      1.00000    dummy
#  1:  0.0004305339        3.2964      1.51680    transmit
#  2:  -0.000430742             1      1.00000    transmit
#  3:   0.002095046        12.205      1.43384    transmit
#  4:  0.0003847703          44.9      1.00000    transmit
#  5:    0.00246542        12.554      1.43384    transmit
#  6:   0.001092051          3.07      1.00000    transmit
#  7:    -0.0017007        3.7206      1.61266    transmit
#  8:  -0.001734677            90      1.00000    transmit
#  9:    0.01195769        2.2284      1.79500    transmit
# 10:  -0.006471944        10.015      1.49782    transmit
# 11:  -0.000446832        18.503      1.00000    transmit
# 12:  0.0002522932        1.4245      1.75500    transmit
# 13:  -0.006396137          3.35      1.00000    transmit
# 14:  -0.003503107        1.8953      1.84668    transmit
# 15:   0.003549441        1.5585      1.53996    transmit
# 16:  -0.008402177        38.179      1.00000    transmit
# 17:             0           1.5      1.00000    transmit
# 18:   0.005414534        5.1093      1.48749    transmit
# 19:   0.007640442           1.2      1.00000    transmit
# 20:     -0.012833        1.0289      1.84668    transmit
# 21:   0.007370382             5      1.00000    transmit
# 22:   0.002818893        1.8953      1.84668    transmit
# 23:   0.001979525        1.1926      1.59319    transmit
# 24:    -0.0110053           3.1      1.00000    transmit
# 25:  -0.002172399        1.0826      1.75500    transmit
# 26:   -0.00798657          4.19      1.00000    transmit
# 27:   0.006527084        1.9746      1.77250    transmit
# 28:   0.002009719           0.1      1.00000    transmit
# 29:   0.009486794        2.7439      1.64000    transmit
# 30: -0.0006071306        1.0289      1.84668    transmit
# 31:   -0.00343283           6.5      1.00000    transmit
# 32:             0       0.98892      1.51680    transmit
# 33:            -0         74.22      1.00000    transmit
# 34:             0             0      1.00000    dummy
# <InteractiveLayout size 432x288 with 1 Axes>
# <RayFanFigure size 432x288 with 4 Axes>
# <RayFanFigure size 432x288 with 4 Axes>
# <SpotDiagramFigure size 432x288 with 2 Axes>

# %%
from rayoptics.seq.medium import InterpolatedGlass

gCaF2 = InterpolatedGlass('CaF2', [
    (1013.98, 1.42879),
    (852.11, 1.43002),
    (706.62, 1.43166),
    (656.2725, 1.43245), 
    (643.85, 1.43267),
    (632.80, 1.43288),
    (589.29, 1.43380),
    (587.5618, 1.43384),
    (546.08, 1.43492),
    (486.1327, 1.43700),
    (479.99, 1.43726),
    (435.84, 1.43946),
    (404.66, 1.44148),
    (365.02, 1.44488)])

opm = OpticalModel()
sm  = opm.seq_model
osp = opm.optical_spec
pm = opm.parax_model
osp.pupil = PupilSpec(osp, key=['image', 'f/#'], value=2.89)
osp.field_of_view = FieldSpec(osp, key=['object', 'angle'], flds=[0., 3.14])
osp.spectral_region = WvlSpec([(486.1327, 0.5), (587.5618, 1.0), (656.2725, 0.5)], ref_wl=1)
opm.system_spec.title = 'JP2019-152887 Example 3 (Nikon AF-S Nikkor 400mm f/2.8 E FL ED VR)'
opm.system_spec.dimensions = 'MM'
opm.radius_mode = True
sm.gaps[0].thi=1e10
sm.add_surface([1200.37,5,'J-BK7A','Hikari'])    # 1.5168,63.88]) 64.14
sm.ifcs[sm.cur_surface].max_aperture = 69.61
sm.add_surface([1199.79,1])
sm.ifcs[sm.cur_surface].max_aperture = 69.61
sm.add_surface([207.079,17.5,1.43384,95.26])
sm.gaps[sm.cur_surface].medium = gCaF2
sm.ifcs[sm.cur_surface].max_aperture = 68.61
sm.add_surface([-1127.53,44.9])
sm.ifcs[sm.cur_surface].max_aperture = 68.61
sm.add_surface([175.97,18,1.43384,95.26])
sm.gaps[sm.cur_surface].medium = gCaF2
sm.ifcs[sm.cur_surface].max_aperture = 57.61
sm.add_surface([-397.271,3.07])
sm.ifcs[sm.cur_surface].max_aperture = 57.61
sm.add_surface([-360.24,6,'J-KZFH1','Hikari'])    # 1.61266,44.46
sm.ifcs[sm.cur_surface].max_aperture = 55.36
sm.add_surface([353.184,90])
sm.ifcs[sm.cur_surface].max_aperture = 55.36
sm.add_surface([66.4844,4,'J-LASF017','Hikari'])    # 1.795,45.32   45.31
sm.ifcs[sm.cur_surface].max_aperture = 34.61
sm.add_surface([45.9182,15,'J-FKH1','Hikari'])    # 1.49782,82.54   82.57
sm.ifcs[sm.cur_surface].max_aperture = 31.61
sm.add_surface([1114.11,18.503])
sm.ifcs[sm.cur_surface].max_aperture = 31.61
sm.add_surface([2992.55,2.5,'J-LASKH2','Hikari'])  # 1.755,52.34
sm.ifcs[sm.cur_surface].max_aperture = 24.11
sm.add_surface([118.04,3.35])
sm.ifcs[sm.cur_surface].max_aperture = 23.36
sm.add_surface([-241.694,3.5,'J-SF03','Hikari'])    #1.84668,23.83
sm.ifcs[sm.cur_surface].max_aperture = 23.36
sm.add_surface([-86.4136,2.4,'J-BAK2','Hikari'])   # 1.53996,59.52
sm.ifcs[sm.cur_surface].max_aperture = 23.36
sm.add_surface([64.2643,38.179])
sm.ifcs[sm.cur_surface].max_aperture = 23.36
sm.add_surface([0,1.5])
sm.set_stop()
sm.ifcs[sm.cur_surface].max_aperture = 18.979
sm.add_surface([90.0336,7.6,'J-FK5','Hikari'])     # 1.48749,70.43   70.31
sm.ifcs[sm.cur_surface].max_aperture = 19.36
sm.add_surface([-63.8039,1.2])
sm.ifcs[sm.cur_surface].max_aperture = 19.36
sm.add_surface([-65.9768,1.9,'J-SF03','Hikari'])    #1.84668,23.83
sm.ifcs[sm.cur_surface].max_aperture = 18.36
sm.add_surface([-114.876,5])
sm.ifcs[sm.cur_surface].max_aperture = 18.36
sm.add_surface([300.359,3.5,'J-SF03','Hikari'])    # 1.84668,23.83
sm.ifcs[sm.cur_surface].max_aperture = 18.36
sm.add_surface([-128.056,1.9,'J-PSKH1', 'Hikari'])  # 1.59319,67.94   67.90
sm.ifcs[sm.cur_surface].max_aperture = 18.36
sm.add_surface([53.9004,3.1])
sm.ifcs[sm.cur_surface].max_aperture = 18.36
sm.add_surface([-347.542,1.9,'J-LASKH2','Hikari'])  # 1.755,52.33   52.34
sm.ifcs[sm.cur_surface].max_aperture = 17.36
sm.add_surface([94.5337,4.19])
sm.ifcs[sm.cur_surface].max_aperture = 17.36
sm.add_surface([118.353,3.5,'J-LASF016','Hikari'])  # 1.7725,49.68  49.62
sm.ifcs[sm.cur_surface].max_aperture = 16.86
sm.add_surface([-384.382,0.1])
sm.ifcs[sm.cur_surface].max_aperture = 16.86
sm.add_surface([67.4622,4.5,'J-LAK01','Hikari'])    # 1.64,60.14  60.20  
sm.ifcs[sm.cur_surface].max_aperture = 17.11
sm.add_surface([-340.421,1.9,'J-SF03','Hikari'])    # 1.84668,23.83
sm.ifcs[sm.cur_surface].max_aperture = 17.11
sm.add_surface([246.642,6.5])
sm.ifcs[sm.cur_surface].max_aperture = 17.11
sm.add_surface([0,1.5,'J-BK7A','Hikari'])           # 1.5168,63.88 64.14
sm.ifcs[sm.cur_surface].max_aperture = 17.86
sm.add_surface([0,74.22])
sm.ifcs[sm.cur_surface].max_aperture = 17.86
sm.list_surfaces()
sm.list_gaps()
sm.do_apertures = False
opm.update_model()
apply_paraxial_vignetting(opm)
layout_plt = plt.figure(FigureClass=InteractiveLayout, opt_model=opm, do_draw_rays=True, do_paraxial_layout=False,
                        is_dark=isdark).plot()
sm.list_model()
# List the optical specifications
pm.first_order_data()
# List the paraxial model
pm.list_lens()
# Plot the transverse ray aberrations
abr_plt = plt.figure(FigureClass=RayFanFigure, opt_model=opm,
          data_type='Ray', scale_type=Fit.All_Same, is_dark=isdark).plot()
# Plot the wavefront aberration
wav_plt = plt.figure(FigureClass=RayFanFigure, opt_model=opm,
          data_type='OPD', scale_type=Fit.All_Same, is_dark=isdark).plot()
# Plot spot diagrams
spot_plt = plt.figure(FigureClass=SpotDiagramFigure, opt_model=opm,
                      scale_type=Fit.User_Scale, user_scale_value=0.1, is_dark=isdark).plot()
# Out:
# 0 Surface(lbl='Obj', profile=Spherical(c=0.0), interact_mode=dummy)
# 1 Surface(profile=Spherical(c=0.000833076468089006), interact_mode=transmit)
# 2 Surface(profile=Spherical(c=0.0008334791921919669), interact_mode=transmit)
# 3 Surface(profile=Spherical(c=0.004829074894122533), interact_mode=transmit)
# 4 Surface(profile=Spherical(c=-0.0008868943620125407), interact_mode=transmit)
# 5 Surface(profile=Spherical(c=0.005682786838665682), interact_mode=transmit)
# 6 Surface(profile=Spherical(c=-0.002517173415628123), interact_mode=transmit)
# 7 Surface(profile=Spherical(c=-0.00277592715967133), interact_mode=transmit)
# 8 Surface(profile=Spherical(c=0.002831385340219262), interact_mode=transmit)
# 9 Surface(profile=Spherical(c=0.015041122428720122), interact_mode=transmit)
# 10 Surface(profile=Spherical(c=0.021777857145968266), interact_mode=transmit)
# 11 Surface(profile=Spherical(c=0.0008975774384935061), interact_mode=transmit)
# 12 Surface(profile=Spherical(c=0.00033416317187682745), interact_mode=transmit)
# 13 Surface(profile=Spherical(c=0.008471704506946797), interact_mode=transmit)
# 14 Surface(profile=Spherical(c=-0.004137463073142072), interact_mode=transmit)
# 15 Surface(profile=Spherical(c=-0.011572252515807697), interact_mode=transmit)
# 16 Surface(profile=Spherical(c=0.015560739010617091), interact_mode=transmit)
# 17 Surface(profile=Spherical(c=0.0), interact_mode=transmit)
# 18 Surface(profile=Spherical(c=0.011106964511026994), interact_mode=transmit)
# 19 Surface(profile=Spherical(c=-0.015673023122411013), interact_mode=transmit)
# 20 Surface(profile=Spherical(c=-0.015156843011482825), interact_mode=transmit)
# 21 Surface(profile=Spherical(c=-0.008705038476270065), interact_mode=transmit)
# 22 Surface(profile=Spherical(c=0.0033293492121095093), interact_mode=transmit)
# 23 Surface(profile=Spherical(c=-0.007809083525957393), interact_mode=transmit)
# 24 Surface(profile=Spherical(c=0.01855273801307597), interact_mode=transmit)
# 25 Surface(profile=Spherical(c=-0.0028773500756743074), interact_mode=transmit)
# 26 Surface(profile=Spherical(c=0.010578238236734625), interact_mode=transmit)
# 27 Surface(profile=Spherical(c=0.00844929997549703), interact_mode=transmit)
# 28 Surface(profile=Spherical(c=-0.002601578637917488), interact_mode=transmit)
# 29 Surface(profile=Spherical(c=0.014823115759640215), interact_mode=transmit)
# 30 Surface(profile=Spherical(c=-0.0029375391059893487), interact_mode=transmit)
# 31 Surface(profile=Spherical(c=0.0040544595000040545), interact_mode=transmit)
# 32 Surface(profile=Spherical(c=0.0), interact_mode=transmit)
# 33 Surface(profile=Spherical(c=0.0), interact_mode=transmit)
# 34 Surface(lbl='Img', profile=Spherical(c=0.0), interact_mode=dummy)
# 0 Gap(t=10000000000.0, medium=Air())
# 1 Gap(t=5, medium=HikariGlass('J-BK7A'))
# 2 Gap(t=1, medium=Air())
# 3 Gap(t=17.5, medium=InterpolatedGlass('CaF2', cat='', wvls=[1013.98, 852.11, 706.62, 656.2725, 643.85, 632.8, 589.29, 587.5618, 546.08, 486.1327, 479.99, 435.84, 404.66, 365.02], rndx=[1.42879, 1.43002, 1.43166, 1.43245, 1.43267, 1.43288, 1.4338, 1.43384, 1.43492, 1.437, 1.43726, 1.43946, 1.44148, 1.44488]))
# 4 Gap(t=44.9, medium=Air())
# 5 Gap(t=18, medium=InterpolatedGlass('CaF2', cat='', wvls=[1013.98, 852.11, 706.62, 656.2725, 643.85, 632.8, 589.29, 587.5618, 546.08, 486.1327, 479.99, 435.84, 404.66, 365.02], rndx=[1.42879, 1.43002, 1.43166, 1.43245, 1.43267, 1.43288, 1.4338, 1.43384, 1.43492, 1.437, 1.43726, 1.43946, 1.44148, 1.44488]))
# 6 Gap(t=3.07, medium=Air())
# 7 Gap(t=6, medium=HikariGlass('J-KZFH1'))
# 8 Gap(t=90, medium=Air())
# 9 Gap(t=4, medium=HikariGlass('J-LASF017'))
# 10 Gap(t=15, medium=HikariGlass('J-FKH1'))
# 11 Gap(t=18.503, medium=Air())
# 12 Gap(t=2.5, medium=HikariGlass('J-LASKH2'))
# 13 Gap(t=3.35, medium=Air())
# 14 Gap(t=3.5, medium=HikariGlass('J-SF03'))
# 15 Gap(t=2.4, medium=HikariGlass('J-BAK2'))
# 16 Gap(t=38.179, medium=Air())
# 17 Gap(t=1.5, medium=Air())
# 18 Gap(t=7.6, medium=HikariGlass('J-FK5'))
# 19 Gap(t=1.2, medium=Air())
# 20 Gap(t=1.9, medium=HikariGlass('J-SF03'))
# 21 Gap(t=5, medium=Air())
# 22 Gap(t=3.5, medium=HikariGlass('J-SF03'))
# 23 Gap(t=1.9, medium=HikariGlass('J-PSKH1'))
# 24 Gap(t=3.1, medium=Air())
# 25 Gap(t=1.9, medium=HikariGlass('J-LASKH2'))
# 26 Gap(t=4.19, medium=Air())
# 27 Gap(t=3.5, medium=HikariGlass('J-LASF016'))
# 28 Gap(t=0.1, medium=Air())
# 29 Gap(t=4.5, medium=HikariGlass('J-LAK01'))
# 30 Gap(t=1.9, medium=HikariGlass('J-SF03'))
# 31 Gap(t=6.5, medium=Air())
# 32 Gap(t=1.5, medium=HikariGlass('J-BK7A'))
# 33 Gap(t=74.22, medium=Air())
#              r            t        medium     mode   zdr      sd
#  Obj:     0.000000  1.00000e+10       air             1      1.0000
#    1:  1200.370000      5.00000    J-BK7A             1      69.610
#    2:  1199.790000      1.00000       air             1      69.610
#    3:   207.079000      17.5000      CaF2             1      68.610
#    4: -1127.530000      44.9000       air             1      68.610
#    5:   175.970000      18.0000      CaF2             1      57.610
#    6:  -397.271000      3.07000       air             1      57.610
#    7:  -360.240000      6.00000   J-KZFH1             1      55.360
#    8:   353.184000      90.0000       air             1      55.360
#    9:    66.484400      4.00000 J-LASF017             1      34.610
#  0: -5.48583e+08     0.0548583
#  1:     -56.4093     0.0791444
#  2:     -56.1484     0.0549589
#  3:     -56.0935      0.172477
#  4:     -53.9884       0.19325
#  5:     -45.3114      0.304962
#  6:      -41.483      0.350264
#  7:     -40.4077      0.281542
#  8:     -39.3602      0.213265
#  9:     -20.1664      0.454408
# 10:     -19.1538      0.330446
# 11:     -15.8445      0.323366
# 12:     -9.86124      0.325854
# 13:     -9.39706      0.265749
# 14:      -8.5068       0.23595
# 15:      -8.0596      0.264555
# 16:      -7.6473      0.200301
# 17:  -2.1721e-08      0.200301
# 18:     0.300452      0.198674
# 19:      1.31553      0.188623
# 20:      1.54188       0.20841
# 21:      1.75631      0.195465
# 22:      2.73364       0.18776
# 23:       3.0895      0.181644
# 24:      3.30613      0.218029
# 25:      3.98202       0.22668
# 26:      4.22742      0.260442
# 27:      5.31868      0.225727
# 28:       5.7644      0.214142
# 29:      5.78581      0.159253
# 30:      6.22279      0.163031
# 31:      6.39053      0.184968
# 32:      7.59282      0.184968
# 33:      7.77574      0.184968
# 34:      21.5041      0.184968
#
#             power           tau        index    type
#  0:             0         1e+10      1.00000    dummy
#  1:  0.0004305339        3.2964      1.51680    transmit
#  2: -0.0004307421             1      1.00000    transmit
#  3:   0.002095046        12.205      1.43384    transmit
#  4:  0.0003847703          44.9      1.00000    transmit
#  5:    0.00246542        12.554      1.43384    transmit
#  6:   0.001092051          3.07      1.00000    transmit
#  7:    -0.0017007        3.7206      1.61266    transmit
#  8:  -0.001734677            90      1.00000    transmit
#  9:    0.01195769        2.2284      1.79500    transmit
# 10:  -0.006471944        10.015      1.49782    transmit
# 11:  -0.000446832        18.503      1.00000    transmit
# 12:  0.0002522932        1.4245      1.75500    transmit
# 13:  -0.006396137          3.35      1.00000    transmit
# 14:  -0.003503025        1.8953      1.84666    transmit
# 15:    0.00354921        1.5585      1.53996    transmit
# 16:  -0.008402177        38.179      1.00000    transmit
# 17:             0           1.5      1.00000    transmit
# 18:   0.005414534        5.1093      1.48749    transmit
# 19:   0.007640442           1.2      1.00000    transmit
# 20:   -0.01283269        1.0289      1.84666    transmit
# 21:   0.007370208             5      1.00000    transmit
# 22:   0.002818827        1.8953      1.84666    transmit
# 23:   0.001979369        1.1926      1.59319    transmit
# 24:    -0.0110053           3.1      1.00000    transmit
# 25:  -0.002172399        1.0826      1.75500    transmit
# 26:   -0.00798657          4.19      1.00000    transmit
# 27:   0.006527084        1.9746      1.77250    transmit
# 28:    0.00200972           0.1      1.00000    transmit
# 29:   0.009486794        2.7439      1.64000    transmit
# 30: -0.0006070719        1.0289      1.84666    transmit
# 31:  -0.003432749           6.5      1.00000    transmit
# 32:             0       0.98892      1.51680    transmit
# 33:            -0         74.22      1.00000    transmit
# 34:             0             0      1.00000    dummy
# <InteractiveLayout size 432x288 with 1 Axes>
# <RayFanFigure size 432x288 with 4 Axes>
# <RayFanFigure size 432x288 with 4 Axes>
# <SpotDiagramFigure size 432x288 with 2 Axes>
